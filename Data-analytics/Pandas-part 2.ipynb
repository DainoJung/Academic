# %% [markdown]
# # Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2. DataFrame
# ### Import csv file using pandas

# %%
alco2009=pd.read_csv("Data/niaaa-report.csv", index_col="State")
alco2009.head()
# Out:
#          Year  Beer  Wine  Spirits
# State
# Alabama  1977  0.99  0.13     0.84
# Alabama  1978  0.98  0.12     0.88
# Alabama  1979  0.98  0.12     0.84
# Alabama  1980  0.96  0.16     0.74
# Alabama  1981  1.00  0.19     0.73

# %% [markdown]
# ### DataFrame supports broadcasting
# #### if a column does not exist, Pandas automatically creates a new column

# %%
alco2009["Total"]=0
alco2009.head()
# Out:
#          Year  Beer  Wine  Spirits  Total
# State
# Alabama  1977  0.99  0.13     0.84      0
# Alabama  1978  0.98  0.12     0.88      0
# Alabama  1979  0.98  0.12     0.84      0
# Alabama  1980  0.96  0.16     0.74      0
# Alabama  1981  1.00  0.19     0.73      0

# %%
alco2009.index.values
# Out:
# array(['Alabama', 'Alabama', 'Alabama', ..., 'Wyoming', 'Wyoming',
#        'Wyoming'], dtype=object)

# %%
alco2009.columns.values
# Out:
# array(['Year', 'Beer', 'Wine', 'Spirits', 'Total'], dtype=object)

# %% [markdown]
# ### Indexing

# %%
s_states=[state for state in alco2009.index if state[0]=='S']+["Samoa"]
drinks=list(alco2009.columns)+["Water"]
nan_alco=alco2009.reindex(s_states, columns=drinks)
nan_alco
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 3
#       1 s_states=[state for state in alco2009.index if state[0]=='S']+["Samoa"]
#       2 drinks=list(alco2009.columns)+["Water"]
# ----> 3 nan_alco=alco2009.reindex(s_states, columns=drinks)
#       4 nan_alco
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:5378, in DataFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5359 @doc(
#    5360     NDFrame.reindex,
#    5361     klass=_shared_doc_kwargs["klass"],
#    (...)
#    5376     tolerance=None,
#    5377 ) -> DataFrame:
# -> 5378     return super().reindex(
#    5379         labels=labels,
#    5380         index=index,
#    5381         columns=columns,
#    5382         axis=axis,
#    5383         method=method,
#    5384         copy=copy,
#    5385         level=level,
#    5386         fill_value=fill_value,
#    5387         limit=limit,
#    5388         tolerance=tolerance,
#    5389     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:5610, in NDFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5607     return self._reindex_multi(axes, copy, fill_value)
#    5609 # perform the reindex on the axes
# -> 5610 return self._reindex_axes(
#    5611     axes, level, limit, tolerance, method, fill_value, copy
#    5612 ).__finalize__(self, method="reindex")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:5633, in NDFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    5630     continue
#    5632 ax = self._get_axis(a)
# -> 5633 new_index, indexer = ax.reindex(
#    5634     labels, level=level, limit=limit, tolerance=tolerance, method=method
#    5635 )
#    5637 axis = self._get_axis_number(a)
#    5638 obj = obj._reindex_with_indexers(
#    5639     {axis: [new_index, indexer]},
#    5640     fill_value=fill_value,
#    5641     copy=copy,
#    5642     allow_dups=False,
#    5643 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:4429, in Index.reindex(self, target, method, level, limit, tolerance)
#    4426     raise ValueError("cannot handle a non-unique multi-index!")
#    4427 elif not self.is_unique:
#    4428     # GH#42568
# -> 4429     raise ValueError("cannot reindex on an axis with duplicate labels")
#    4430 else:
#    4431     indexer, _ = self.get_indexer_non_unique(target)
#
# ValueError: cannot reindex on an axis with duplicate labels

# %% [markdown]
# # Hierarchical Indexing, MultiIndexing

# %%
alco=pd.read_csv("niaaa-report.csv", index_col=["State", "Year"])
alco
# Out:
#               Beer  Wine  Spirits
# State   Year
# Alabama 1977  0.99  0.13     0.84
#         1978  0.98  0.12     0.88
#         1979  0.98  0.12     0.84
#         1980  0.96  0.16     0.74
#         1981  1.00  0.19     0.73
# ...            ...   ...      ...
# Wyoming 2005  1.21  0.23     0.97
#         2006  1.47  0.23     1.05
#         2007  1.49  0.23     1.10
#         2008  1.54  0.23     1.12
#         2009  1.45  0.22     1.10
#
# [1683 rows x 3 columns]

# %% [markdown]
# ## df.loc[(index pair), (column list)]

# %%
alco.loc[('Wyoming', 1999)].head()
# Out:
# Beer       1.41
# Wine       0.18
# Spirits    0.84
# Name: (Wyoming, 1999), dtype: float64

# %%
alco.loc[('Alabama', 1978):('Wyoming', 1999)]
# Out:
#               Beer  Wine  Spirits
# State   Year
# Alabama 1978  0.98  0.12     0.88
#         1979  0.98  0.12     0.84
#         1980  0.96  0.16     0.74
#         1981  1.00  0.19     0.73
#         1982  1.00  0.18     0.72
# ...            ...   ...      ...
# Wyoming 1995  1.34  0.16     0.80
#         1996  1.37  0.16     0.81
#         1997  1.36  0.17     0.81
#         1998  1.38  0.20     0.81
#         1999  1.41  0.18     0.84
#
# [1672 rows x 3 columns]

# %%
alco.loc[('Wyoming', 1999), ('Beer', 'Wine')]
# Out:
# Beer    1.41
# Wine    0.18
# Name: (Wyoming, 1999), dtype: float64

# %% [markdown]
# ## Handling Missing Values

# %%
nan_alco.dropna(how="all") # drop columns in which all the values are nan
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 nan_alco.dropna(how="all")
#
# NameError: name 'nan_alco' is not defined

# %%
nan_alco.dropna(how="all", axis=1) # drop columns in which all the values are nan
# Out:
#                 Beer  Wine  Spirits
# State
# South Carolina  1.36  0.24     0.77
# South Dakota    1.53  0.22     0.88
# Samoa            NaN   NaN      NaN

# %%
nan_alco.isnull()
# Out:
#                  Beer   Wine  Spirits  Water
# State
# South Carolina  False  False    False   True
# South Dakota    False  False    False   True
# Samoa            True   True     True   True

# %%
nan_alco.notnull()
# Out:
#                  Beer   Wine  Spirits  Water
# State
# South Carolina   True   True     True  False
# South Dakota     True   True     True  False
# Samoa           False  False    False  False

# %%
nan_alco[nan_alco.isnull()]=0
nan_alco
# Out:
#                 Beer  Wine  Spirits  Water
# State
# South Carolina  1.36  0.24     0.77    0.0
# South Dakota    1.53  0.22     0.88    0.0
# Samoa           0.00  0.00     0.00    0.0

# %%
nan_alco.fillna(0)
# Out:
#                 Beer  Wine  Spirits  Water
# State
# South Carolina  1.36  0.24     0.77    0.0
# South Dakota    1.53  0.22     0.88    0.0
# Samoa           0.00  0.00     0.00    0.0

# %%
nan_alco.loc["Samoa"].fillna(0, inplace=True)

# %%
nan_alco
# Out:
#                 Beer  Wine  Spirits  Water
# State
# South Carolina  1.36  0.24     0.77    NaN
# South Dakota    1.53  0.22     0.88    NaN
# Samoa           0.00  0.00     0.00    0.0

# %% [markdown]
# # Concatenating DataFrame

# %%
population=pd.read_csv("population.csv", index_col="State")
population.head()
# Out:
#             Population
# State
# Alabama      4,780,131
# Alaska         710,249
# Arizona      6,392,301
# Arkansas     2,916,025
# California  37,254,522

# %%
pd.concat([alco2009, population], axis=1).head()
# Out:
#             Beer  Wine  Spirits  Population
# State
# Alabama     1.20  0.22     0.58   4,780,131
# Alaska      1.31  0.54     1.16     710,249
# Arizona     1.19  0.38     0.74   6,392,301
# Arkansas    1.07  0.17     0.60   2,916,025
# California  1.05  0.55     0.73  37,254,522

# %% [markdown]
# ## Sorting Data

# %%
alco2009.max()
# Out:
# Beer       1.72
# Wine       1.00
# Spirits    1.82
# dtype: float64

# %%
alco2009.max(axis=1)
# Out:
# State
# Alabama                 1.20
# Alaska                  1.31
# Arizona                 1.19
# Arkansas                1.07
# California              1.05
# Colorado                1.22
# Connecticut             0.89
# Delaware                1.31
# District of Columbia    1.64
# Florida                 1.21
# Georgia                 1.08
# Hawaii                  1.30
# Idaho                   1.05
# Illinois                1.22
# Indiana                 1.09
# Iowa                    1.42
# Kansas                  1.18
# Kentucky                1.11
# Louisiana               1.50
# Maine                   1.24
# Maryland                0.97
# Massachusetts           1.02
# Michigan                1.10
# Minnesota               1.19
# Mississippi             1.41
# Missouri                1.30
# Montana                 1.66
# Nebraska                1.46
# Nevada                  1.57
# New Hampshire           1.82
# New Jersey              0.92
# New Mexico              1.37
# New York                0.91
# North Carolina          1.10
# North Dakota            1.63
# Ohio                    1.28
# Oklahoma                1.18
# Oregon                  1.28
# Pennsylvania            1.35
# Rhode Island            1.10
# South Carolina          1.36
# South Dakota            1.53
# Tennessee               1.05
# Texas                   1.42
# Utah                    0.70
# Vermont                 1.36
# Virginia                1.11
# Washington              1.09
# West Virginia           1.24
# Wisconsin               1.49
# Wyoming                 1.45
# dtype: float64

# %%
alco.groupby("Year").sum()
# Out:
#        Beer   Wine  Spirits
# Year
# 1977  67.92  14.14    59.52
# 1978  69.51  15.12    60.08
# 1979  71.39  15.72    58.73
