# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.kobis.or.kr/kobis/business/mast/thea/findTheaterInfoList.do'

response = requests.get(url)

if response.status_code == 200:
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    print(soup)

else : 
    print(response.status_code)
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <title>KOFIC 영화관 입장권 통합전산망 :: 영화상영관 정보</title>
# <!-- 공통 js/css -->
# <!--[if IE]>
# <script src="/kobis/web/comm/commjs/html5shiv.js"></script>
# <![endif]-->
# <!-- 기본 css -->
# <link href="/kobis/web/comm/commcss/default.css" rel="stylesheet" type="text/css"/>
# <link href="/kobis/web/comm/commcss/jquery-ui-1.12.1.min.css" rel="stylesheet" type="text/css">
# <link href="/kobis/web/comm/commcss/common.css" rel="stylesheet" type="text/css"/>
# <script src="/kobis/web/comm/commjs/jquery-1.12.4.js" type="text/javascript"></script>
# <script src="/kobis/web/comm/commjs/jquery.dotdotdot.min.js" type="text/javascript"></script>
# <script src="/kobis/web/comm/commjs/jquery.bxslider.js" type="text/javascript"></script>
# <script src="/kobis/web/comm/commjs/comm_script.js" type="text/javascript"></script>
# <script src="/kobis/web/comm/commjs/jquery-ui-1.13.2.min.js" type="text/javascript"></script>
# <script src="/kobis/web/comm/commjs/jquery.ui.datepicker-ko.js" type="text/javascript"></script>
# <script src="/kobis/web/comm/commjs/kobis.js" type="text/javascript"></script>
# <link href="/kobis/web/comm/commcss/cont.css" rel="stylesheet" type="text/css"/>
# <link href="/kobis/web/comm/commcss/kobis.css" rel="stylesheet" type="text/css"/>
# <script src="/kobis/web/comm/commjs/jcarousellite_1.0.1.js" type="text/javascript"></script>
# <script src="/kobis/web/comm/commjs/IGuide.js" type="text/javascript"></script>
# <script src="/kobis/web/comm/commjs/jquery.cookie.js" type="text/javascript"></script>
# <script src="/kobis/web/comm/commjs/dialogStyle.js" type="text/javascript"></script>
# <script src="/kobis/web/comm/commjs/layerpopup.js" type="text/javascript"></script>
# <script src="/kobis/web/comm/commjs/innershiv.js" type="text/javascript"></script>
# <script src="/kobis/web/comm/commjs/detailLayer.js" type="text/javascript"></script>
# <script src="/kobis/web/comm/online/js/chart.min.js" type="text/javascript"></script>
# <script src="/kobis/web/comm/online/js/jquery.peity.js" type="text/javascript"></script>
# <!-- 상세Layer용 -->
# <script type="text/javascript">
#
# 	$(function(){
#
# 		//엔터검색
# 		if(!$("#wrap").attr("class")== false){
# 			if($("#wrap").attr("class").indexOf("admin")<0){
# 				$("form").find(":text:enabled:not([readonly='readonly'])").each(function(){
# 					$(this).keypress(function(event){
# 						if(event.which=='13'){
# 							if($('#pageIndex').val() != 'undefined') {
# 								$('#pageIndex').val("1");
# 							}
# 							fn_searchList();
# 						}
# 					});
# 				});
# 			}
# 		}
#
# 		$( ".tf_cal" ).datepicker({
# 			dateFormat: 'yy-mm-dd',
# 			prevText: '이전 달',
# 			nextText: '다음 달',
# 			monthNames: ['1월','2월','3월','4월','5월','6월','7월','8월','9월','10월','11월','12월'],
# 			monthNamesShort: ['1월','2월','3월','4월','5월','6월','7월','8월','9월','10월','11월','12월'],
# 			dayNames: ['일','월','화','수','목','금','토'],
# 			dayNamesShort: ['일','월','화','수','목','금','토'],
# 			dayNamesMin: ['일','월','화','수','목','금','토'],
# 			showMonthAfterYear: true,
# 			yearSuffix: '년'
# 	    });
#
# 		//삭제 영화인 스타일 설정
# 		$(".del").find("td").css({"color":"red"}).find("a").css({"color":"red"});
#
# 		fn_setSearchValue();
#
# 		$("#sWideareaCd").change(function(){
# 			makeBasareaCd($(this).val(), $("select[name='sBasareaCd']").get(0), '');
# 		});
#
# 		function makeBasareaCd(wideareaCd, selectObj, selectedBasareaCd) {
# 			$("#sBasareaCd").next(".slt_cover").children().text("전체");
# 			$("#sBasareaCd").val("");
# 			$.ajax({
# 				type : "POST",
# 				url  : "findBasareaCdList.do",
# 				dataType : "json",
# 				data : { sWideareaCd: wideareaCd},
# 				success : function(data){
# 					var basareaCdList = data.basareaCdList;
# 					$(selectObj).find("option:not(:first-child)").remove();
# 					for(var i = 0; i < basareaCdList.length; i++){
# 						if(selectObj){
# 							if(selectedBasareaCd != basareaCdList[i].cd){
# 								$(selectObj).append($("<option value=\""+ basareaCdList[i].cd +"\">" + basareaCdList[i].cdNm+"</option>"));
# 							}else{
# 								$(selectObj).append($("<option value=\""+ basareaCdList[i].cd +"\" selected=\"selected\">" + basareaCdList[i].cdNm+"</option>"));
# 							}
# 						}
# 					}
# 				}
# 			});
# 		}
# 	});
# 	function fn_excel() {
# 		$("#searchForm").attr("action", "findTheaterInfoListXls.do").submit();
# 	}
# 	function fn_detail(p_event, p_btn, theaCd) {
#
# 		var p_param = setQueryStringByObj({
# 			theaCd: theaCd
# 		});
#
# 		$.ajax({
# 			url : "findTheaterCodeLayer.do",
# 			data : p_param,
# 			dataType : "html",
# 			success : function(msg) {
# 				$("#div_theaterDetail").html(msg);
# 			},
# 			complete : function(){
# 				$( "#div_theaterDetail" ).dialog({
# 					width : 'auto',
# 					height : 'auto',
# 					resizable : false,
# 					position : {my: 'center', at: 'center', of: window}
# 				});
#
# 				$( "#div_theaterDetail" ).dialog("widget").find('.ui-dialog-titlebar-close').remove();
# 			}
# 		});
#
# 	}
# 	function setQueryStringByObj(p_objParamSet) {
# 		var queryString = "";
# 		var i = 0;
# 		$.each(p_objParamSet, function(paramName, paramValue) {
# 			queryString = queryString + (i++ == 0? "": "&") + paramName + "=" + paramValue;
# 		});
# 		return queryString;
# 	}
#
# 	function goPage(page) {
#
# 		$("#pageIndex").val(page);
# 		//$("#searchForm").attr("action", "findTheaterInfoList.do").submit();
# 		$.ajax({
# 			type: "post",
# 			url: $("#searchForm").attr("action"),
# 			data: $("#searchForm").serialize(),
# 			beforeSend: function(xhr){
# 				pageMoveSt($($('table')[0]).attr("class"));
# 			},
# 			success: function(msg) {
# 				$(".total").html($(msg).find(".total").html());
# 				$(".tbl_comm").html($(msg).find(".tbl_comm").html());
# 				$("#pagingForm").html($(msg).find("#pagingForm").html());
# 				$(".pageLoading").remove();
# 			}
# 		});
#
#
# 	}
#
# 	// 초성 검색
# 	function fn_chosung_search(chosung){
# 		var sForm = document.searchForm;
# 		if(chosung){
# 			sForm.chosung.value=chosung;
# 		}else{
# 			sForm.chosung.value='';
# 		}
# 		sForm.submit();
# 	}
# 	function fn_chosung(Obj){
# 		fn_chosung_search(Obj);
# 	};
# 	//조회 버튼 검색
# 	function fn_searchList(type) {
#
# 		$('#pageIndex').val("1");
# 		if(type=='excel'){
# 			if(!confirm('많은 양의 데이터를 다운로드시 시간이 오래 걸릴 수 있습니다. 엑셀로 다운받으시겠습니까?')) return false
# 			fn_excel();
# 			return false;
# 		}else{ //로딩중 show
# 			$.ajax({
# 				type: "post",
# 				url: $("#searchForm").attr("action"),
# 				data: $("#searchForm").serialize(),
# 				beforeSend: function(xhr){
# 					pageMoveSt($($('table')[0]).attr("class"));
#
# 				},
# 				success: function(msg) {
# 					$(".pageLoading").remove();
# 					$(".total").html($(msg).find(".total").html());
# 					$(".tbl_comm").html($(msg).find(".tbl_comm").html());
# 					$("#pagingForm").html($(msg).find("#pagingForm").html());
# 				}
# 			});
#
# 		}
#
#
# 	}
# 	function fn_excel() {
# 		$("#searchForm").attr("action", "findTheaterInfoListXls.do").submit();
# 	}
# 	// 검색조건 초기화
# 	function fn_searchReset(){
# 		$("#sTheaNm").next(".slt_cover").children().text("전체");
# 		$("#sTheaNm").val("");
#
# 		$("#sTheaCd").next(".slt_cover").children().text("전체");
# 		$('#sTheaCd').val("");
#
# 		$("#sPermYn").next(".slt_cover").children().text("전체");
# 		$("#sPermYn").val("");
#
# 		$("#sJoinYn").next(".slt_cover").children().text("전체");
# 		$('#sJoinYn').val("");
#
# 		$("#sSaleStat").next(".slt_cover").children().text("전체");
# 		$('#sSaleStat').val("");
#
# 		$("#sWideareaCd").next(".slt_cover").children().text("전체");
# 		$("#sWideareaCd").val("");
#
# 		$("#sBasareaCd").next(".slt_cover").children().text("전체");
# 		$("#sBasareaCd").val("");
#
# 		$("#sSenderCd").next(".slt_cover").children().text("전체");
# 		$('#sSenderCd').val("");
#
#
# 		$("#sApproveYn").next(".slt_cover").children().text("전체");
# 		$('#sApproveYn').val("");
#
# 		$("#pageIndex").next(".slt_cover").children().text("전체");
# 		$('#pageIndex').val("");
#
# 	}
#
# 	$(document).ready(function(){
# 		$("#sOrderBy").change(function(e){
#
#         	$("input[name='orderBy']").val($(this).val());
#             fn_searchList();
#         });
#         $('.more').on('click',function(){
# 			$(this).toggleClass('open')
# 			$('.drop').toggle()
# 		});
#
#
#
#
# 	});
#
# 	function fn_setSearchValue() {
# 		$('#sTheaNm').val("");
# 		$('#sTheaCd').val("");
# 		$('#sWideareaCd').val("");
# 		$('#sBasareaCd').val("");
# 		$('#sSenderCd').val("");
# 		$('#sPermYn').val("Y");
# 		$('#sJoinYn').val("Y");
# 		$('#sSaleStat').val("018201");
# 		$('#sApproveYn').val("");
# 		$('#pageIndex').val("1");
# 	}
# 	function btn_more_close(type){
# 		if(type == "more"){
# 			$("input[name='searchOpen']").val("Y");
# 			$(".drop  *").attr("disabled",false);
# 		}else if(type == "close"){
# 			$("input[name='searchOpen']").val("N");
# 		}
# 	}
# </script>
# </link></head>
# <body>
# <!-- <div id="wrap_layer">
# 	<div class="bg"></div>
# 	<p style="position:absolute;top:40%;left:40%;z-index: 10000;"><img src="/kobis/web/comm/images/comm/progressbar.gif" alt="현재 페이지를 로딩중입니다."></p>
# </div> -->
# <div class="mvie1_1" id="wrap">
# <script type="text/javascript">
# 	function mainTopMenuTopView(divName) {
# 		var frm = document.getElementById(divName);
# 		if(frm.style.display != "block") frm.style.display = "block";
# 		else frm.style.display = "none";
# 	}
#
# 	function fn_changeSearch() {
# 		SetCookie("sel_s_type", $("#sel_s_type").val());
# 		var pForm = document.searchMainTopMovie;
#
# 		if($("#sel_s_type").val() == "M") {
# 			pForm.action="/kobis/business/mast/mvie/searchMovieList.do";
# 			$("#inp_solrSearch").attr("name", "sMovName");
# 		} else {
# 			pForm.action="/kobis/business/comm/search/search.do";
# 			$("#inp_solrSearch").attr("name", "queryString");
# 		}
# 	}
#
# 	function fn_mainTopMovieSearch(){
# 		var pForm = document.searchMainTopMovie;
# 		pForm.submit();
# 	}
#
# 	$(document).ready(function() {
# 	    if(GetCookie("sel_s_type") == "T") {
# 	    	$("#sel_s_type").val("T");
#
# 	    	var pForm = document.searchMainTopMovie;
# 	    	pForm.action="/kobis/business/comm/search/search.do";
#
# 	    	$("#inp_solrSearch").attr("name", "queryString");
# 	    }
# 	    $("ul.list_nav > li > a").click(function(){
#
#
# 	    	if($(this).parent().find(".bg_sub ul.nav_sub > li:eq(0)  li.depth3:eq(0)").length >0){
# 	    		$(this).parent().find(".bg_sub ul.nav_sub > li:eq(0)  li.depth3:eq(0) a").click();
# 	    		goDirectPage($(this).parent().find(".bg_sub ul.nav_sub > li:eq(0)  li.depth3:eq(0) a").attr("href"));
# 	    	}else{
# 	    		$(this).parent().find(".bg_sub ul.nav_sub > li:eq(0) a").click();
# 	    		goDirectPage($(this).parent().find(".bg_sub ul.nav_sub > li:eq(0) a").attr("href"));
# 	    	}
#
#
# 	    	if($(this).parent().hasClass("nav5")){
# 	    		/* $(this).attr("href","/kobis/business/stat/online/onlinefindDailyBoxOfficeList.do"); */
# 	    		/* location.href="/kobis/business/stat/online/onlineMain.do"; */
# 	    		location.href="/kobis/business/stat/online/onlineintro.do";
#
# 	    	}
# 	    });
# 	});
# 	function goDirectPage(page){
# 		location.href=page;
# 	}
# </script>
# <link href="/kobis/web/comm/commcss/autoLogout.css" rel="stylesheet" type="text/css">
# <!-- 20221025 30분 자리비움 시 자동 로그아웃 KOFIC과 같은거로 -->
# <script language="javascript" type="text/javascript">
# //자동 로그아웃용 20221025
# function fn_ajaxJsonSua2(url, parameters, options) {
# 	if(url == "" || url == null) {
# 		alert("개발자 오류 : URL이 없습니다.");
# 		return;
# 	}
#
# 	var cache = false;
# 	var async = true;
# 	var type  = "get";
# 	var params = {};
# 	var loading = "Y";
#
# 	if(parameters) {
# 		params = parameters;
#
# 		$.each(params, function(key, value) {
# 			params[key] = encodeURIComponent(value);
# 		});
# 	}
#
# 	if(options) {
# 		if(options["loading"]) {
# 			loading = options["loading"];
# 		}
#
# 		if(options["cache"]) {
# 			cache = options["cache"];
# 		}
#
# 		if(options["async"]) {
# 			async = options["async"];
# 		}
#
# 		if(options["type"]) {
# 			type = options["type"];
# 		}
# 	}
#
# 	$.ajax({
# 		type        : type,
# 		url         : url,
# 		dataType    : "json",
# 		data        : params,
# 		contentType : "application/json+sua",
# 		cache       : cache,
# 		async       : async,
# 		beforeSend  : function(xhr){
# 			if(loading == "Y") {
# 				fn_startLoading();
# 			}
#
# 			if(params["fn_beforeSend"] && window[params["fn_beforeSend"]]) {
# 				window[params["fn_beforeSend"]](data, params);
# 			}
# 		},
# 		success     : function(data){
# 			if(loading == "Y") {
# 				fn_stopLoading();
# 			}
#
# 			if(params["fn_success"] && window[params["fn_success"]]) {
# 				window[params["fn_success"]](data, params);
# 			}
# 	 	},
# 	 	error       : function(data){
# 	 		if(loading == "Y") {
# 	 			fn_stopLoading();
# 	 		}
#
# 	 		try {
# 	 			var errorMsg = JSON.parse(data.responseText);
#
# 	 			if(errorMsg != "") {
# 		 			alert(errorMsg.errorList[0].value);
# 		 		}
# 	 		} catch(e) {}
#
# 			if(params["fn_error"] && window[params["fn_error"]]) {
# 				window[params["fn_error"]](data, params);
# 			}
# 	 	},
# 	 	complete    : function() {
#
# 	 	}
# 	});
# }
#
# var SystemUtils = {
# 	    getMaxZIndex: function (a) {
# 	        if (a == null) {
# 	            a = $("div, span");
# 	        }
# 	        return Math.max.apply(null, $.map(a, function (e, n) {
# 	            return parseInt($(e).css("z-index")) || 1;
# 	        }));
# 	    },
# 	    getDocumentHeight: function () {
# 	        return Math.max(Math.max(document.body.scrollHeight, document.documentElement.scrollHeight), Math.max(document.body.offsetHeight, document.documentElement.offsetHeight), Math.max(document.body.clientHeight, document.documentElement.clientHeight));
# 	    }
# 	};
#
#
# </script>
# <!-- 운영 적용시 if문 삭제 -->
# <div class="minwidth" id="header">
# <div class="hd_top">
# <h1><a class="block" href="/kobis/business/main/main.do"><img alt="KOBIS 영화관 입장권 통합 전산망" src="/kobis/web/comm/images/comm/logo_comm.png"/></a></h1>
# <div class="hd_sch">
# <form action="/kobis/business/mast/mvie/searchMovieList.do" id="searchMainTopMovie" method="post" name="searchMainTopMovie">
# <input name="CSRFToken" type="hidden" value="C_Blc0Gt76azZjdreWoScGTRgQX6b6btzz9FZt1KSZU"/>
# <fieldset>
# <legend class="blind">검색</legend>
# <div class="hd_slt">
# <select class="slt" id="sel_s_type" onchange="fn_changeSearch();">
# <option value="M">영화정보</option>
# <option value="T">통합검색</option>
# </select>
# </div>
# <span class="hd_tf">
# <input class="tf" id="inp_solrSearch" name="sMovName" placeholder="검색어를 입력하세요." type="text" value=""/>
# <input name="sMovLang" type="hidden" value="ko"/>
# </span>
# <button class="btn_sch" onclick="fn_mainTopMovieSearch();return false;" type="button"><span class="ico_comm hidetxt">검색</span></button>
# </fieldset>
# </form>
# </div>
# <span style="bottom: 20px; float: right; display: block; position: relative;">
# <a href="/kobis/business/comm/bord/listMyTip.do?bizLogicType=3"><img alt="" src="/kobis/web/comm/images/main/head_ico1.png" style="margin-right: 4px;"/></a>
# <!-- <a href="/kobis/business/mast/peop/searchPeopleList.do"><img alt="" src="/kobis/web/comm/images/main/head_ico2.png"></a> -->
# </span>
# <div class="gnb_top">
# <ul class="fl">
# <li><a href="/kobis/business/comm/user/openRegiUser.do">회원가입</a></li>
# <li><a href="/kobis/business/comm/user/openLogin.do">로그인</a></li>
# </ul>
# </div>
# </div>
# <!-- 사이트 메뉴 -->
# <div class="minwidth" id="nav">
# <h2 class="blind">사이트 메뉴</h2>
# <ul class="list_nav minwidth" style="min-width: 1260px">
# <li class="depth1 nav1 headerWidth">
# <a class="tit_nav" href="javascript:;">
# 			 				영화정보검색
# 			 			</a>
# <div class="wrap_sub">
# <div class="bg_sub">
# <div class="visu_nav visu_mvie">
# <strong class="depth2">영화</strong>
# <span class="depth3">영화정보</span>
# </div>
# <ul class="nav_sub">
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/mast/mvie/searchMovieList.do">영화</a>
# <ul class="ovf overdepth">
# <li class="depth3">
# <a class="block" href="/kobis/business/mast/mvie/searchMovieList.do">영화정보</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/mast/mvie/findOpenScheduleList.do">개봉스케줄</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/mast/mvie/searchPrdtList.do">한국영화 제작상황판</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/mast/mvie/findDiverMovList.do">독립·예술영화</a>
# </li>
# </ul>
# </li>
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/mast/peop/searchPeopleList.do">영화인</a>
# <ul class="ovf overdepth">
# </ul>
# </li>
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/mast/comp/searchCompanyList.do">영화사</a>
# <ul class="ovf overdepth">
# </ul>
# </li>
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/mast/thea/findTheaterInfoList.do">영화상영관</a>
# <ul class="ovf overdepth">
# <li class="depth3">
# <a class="block" href="/kobis/business/mast/thea/findTheaterInfoList.do">영화상영관정보</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/mast/thea/findAreaTheaterStat.do">지역별 영화상영관현황</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/mast/thea/findShowHistorySc.do">상영내역</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/mast/thea/findTheaterSchedule.do">상영스케줄</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/mast/thea/findScreenQuota.do">스크린쿼터내역</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/mast/thea/findArtScreenStat.do">전용상영관 현황</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/mast/thea/findArtShowHistory.do">전용상영관 상영내역</a>
# </li>
# </ul>
# </li>
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/mast/fest/searchUserFestInfoList.do">영화제</a>
# <ul class="ovf overdepth">
# </ul>
# </li>
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/mast/mvie/searchUserMovCdList.do">코드검색 및 등록</a>
# <ul class="ovf overdepth">
# <li class="depth3">
# <a class="block" href="/kobis/business/mast/mvie/searchUserMovCdList.do">영화코드</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/mast/send/findSenderCodeList.do">전송사업자코드</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/mast/thea/findTheaterCodeList.do">영화상영관코드</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="depth1 nav2 headerWidth">
# <a class="tit_nav" href="javascript:;">
# 			 				박스오피스
# 			 			</a>
# <div class="wrap_sub">
# <div class="bg_sub">
# <div class="visu_nav visu_boxs">
# <strong class="depth2">박스오피스</strong>
# <span class="depth3">일별</span>
# </div>
# <ul class="nav_sub">
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/stat/boxs/findDailyBoxOfficeList.do">박스오피스</a>
# <ul class="ovf overdepth">
# <li class="depth3">
# <a class="block" href="/kobis/business/stat/boxs/findDailyBoxOfficeList.do">일별</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/stat/boxs/findWeeklyBoxOfficeList.do">주간/주말</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/stat/boxs/findMonthlyBoxOfficeList.do">월별</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/stat/boxs/findYearlyBoxOfficeList.do">연도별</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/stat/boxs/findFormerBoxOfficeList.do">역대</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/stat/boxs/findPeriodBoxOfficeList.do">기간별</a>
# </li>
# </ul>
# </li>
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/stat/boxs/findWeekendForeignBoxOfficeList.do">해외 박스오피스</a>
# <ul class="ovf overdepth">
# <li class="depth3">
# <a class="block" href="/kobis/business/stat/boxs/findWeekendForeignBoxOfficeList.do">주말</a>
# </li>
# </ul>
# </li>
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/stat/boxs/findRealTicketList.do">예매율</a>
# <ul class="ovf overdepth">
# <li class="depth3">
# <a class="block" href="/kobis/business/stat/boxs/findRealTicketList.do">실시간</a>
# </li>
# </ul>
# </li>
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/stat/boxs/findDailySeatTicketList.do">좌석점유율</a>
# <ul class="ovf overdepth">
# <li class="depth3">
# <a class="block" href="/kobis/business/stat/boxs/findDailySeatTicketList.do">일별</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/stat/boxs/findWeeklySeatTicketList.do">주간/주말</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/stat/boxs/findPeriodSeatTicketList.do">기간별</a>
# </li>
# </ul>
# </li>
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/stat/boxs/findDailyShowTicketList.do">상영점유율</a>
# <ul class="ovf overdepth">
# <li class="depth3">
# <a class="block" href="/kobis/business/stat/boxs/findDailyShowTicketList.do">일별</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/stat/boxs/findWeeklyShowTicketList.do">주간/주말</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/stat/boxs/findPeriodShowTicketList.do">기간별</a>
# </li>
# </ul>
# </li>
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/stat/boxs/findDailyScreenTicketList.do">스크린점유율</a>
# <ul class="ovf overdepth">
# <li class="depth3">
# <a class="block" href="/kobis/business/stat/boxs/findDailyScreenTicketList.do">일별</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/stat/boxs/findWeeklyScreenTicketList.do">주간/주말</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/stat/boxs/findPeriodScreenTicketList.do">기간별</a>
# </li>
# </ul>
# </li>
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/stat/unfair/findDailyShowFrequency.do">공정신호등</a>
# <ul class="ovf overdepth">
# <li class="depth3">
# <a class="block" href="/kobis/business/stat/unfair/findDailyShowFrequency.do">공정신호등(상영회차별 점유상황)</a>
# </li>
# </ul>
# </li>
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/stat/boxs/findDailyMultichainList.do">체인영화관별 상영현황</a>
# <ul class="ovf overdepth">
# <li class="depth3">
# <a class="block" href="/kobis/business/stat/boxs/findDailyMultichainList.do">멀티체인별 상영현황</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="depth1 nav3 headerWidth">
# <a class="tit_nav" href="javascript:;">
# 			 				테마통계
# 			 			</a>
# <div class="wrap_sub">
# <div class="bg_sub">
# <div class="visu_nav visu_them">
# <strong class="depth2">총 관객수 및 매출액</strong>
# <span class="depth3">연도별</span>
# </div>
# <ul class="nav_sub">
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/stat/them/findYearlyTotalList.do">총 관객수 및 매출액</a>
# <ul class="ovf overdepth">
# <li class="depth3">
# <a class="block" href="/kobis/business/stat/them/findYearlyTotalList.do">연도별</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/stat/them/findMonthlyTotalList.do">월별</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/stat/them/findWeeklyTotalList.do">요일별</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/stat/them/findDailyTotalList.do">일별</a>
# </li>
# </ul>
# </li>
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/stat/them/findNationalityShareList.do">국적별 점유율</a>
# <ul class="ovf overdepth">
# </ul>
# </li>
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/stat/them/findAreaShareList.do">지역별 점유율</a>
# <ul class="ovf overdepth">
# </ul>
# </li>
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/stat/them/findShowTypeShareList.do">상영타입별 점유율</a>
# <ul class="ovf overdepth">
# </ul>
# </li>
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/stat/them/findRatingShareList.do">등급별 점유율</a>
# <ul class="ovf overdepth">
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="depth1 nav4 headerWidth">
# <a class="tit_nav" href="javascript:;">
# 			 				공식통계
# 			 			</a>
# <div class="wrap_sub">
# <div class="bg_sub">
# <div class="visu_nav visu_offc">
# <strong class="depth2">개봉일람</strong>
# <span class="depth3">연도별</span>
# </div>
# <ul class="nav_sub">
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/stat/offc/searchOfficHitTotList.do?searchMode=year">개봉일람</a>
# <ul class="ovf overdepth">
# <li class="depth3">
# <a class="block" href="/kobis/business/stat/offc/searchOfficHitTotList.do?searchMode=year">연도별</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/stat/offc/searchOfficHitTotList.do?searchMode=month">월별</a>
# </li>
# </ul>
# </li>
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/stat/offc/findYearlyBoxOfficeList.do">연도별 박스오피스</a>
# <ul class="ovf overdepth">
# </ul>
# </li>
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/stat/offc/findFormerBoxOfficeList.do">역대 박스오피스</a>
# <ul class="ovf overdepth">
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="depth1 nav5 headerWidth">
# <a class="tit_nav" href="javascript:;">
# 			 				온라인상영관 박스오피스
# 			 			</a>
# <div class="wrap_sub">
# <div class="bg_sub">
# <div class="visu_nav visu_online">
# <strong class="depth2">온라인상영관통합전산망 소개</strong>
# <!-- <span class="depth3">일간 이용순위</span> -->
# </div>
# <ul class="nav_sub">
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/stat/online/onlineintro.do">온라인상영관통합전산망 소개</a>
# <ul class="ovf overdepth">
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="depth1 nav6 headerWidth">
# <a class="tit_nav" href="javascript:;">
# 			 				고객센터
# 			 			</a>
# <div class="wrap_sub">
# <div class="bg_sub">
# <div class="visu_nav visu_cs">
# <strong class="depth2">공지사항</strong>
# <span class="depth3"></span>
# </div>
# <ul class="nav_sub">
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/comm/ntfy/findCustomerNotifyList.do">공지사항</a>
# <ul class="ovf overdepth">
# </ul>
# </li>
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/comm/comm/openKobisIntro.do">KOBIS소개</a>
# <ul class="ovf overdepth">
# <li class="depth3">
# <a class="block" href="/kobis/business/comm/comm/openKobisIntro.do">KOBIS소개</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/comm/comm/openCinemAconnect.do">영화상영관연동안내</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/comm/comm/openMemBerJoin.do">회원가입안내</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/comm/comm/openOffTheater.do">비상설 상영장 가입안내</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/comm/comm/openStatute.do">영비법</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/comm/comm/openSiteMap.do">SITE MAP</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/comm/comm/openPrivacyAgreement.do">개인정보처리방침</a>
# </li>
# <li class="depth3">
# <a class="block" href="/kobis/business/comm/comm/openLocation.do">오시는 길</a>
# </li>
# </ul>
# </li>
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/comm/bord/listMyTip.do?bizLogicType=3">정보수정요청</a>
# <ul class="ovf overdepth">
# <li class="depth3">
# <a class="block" href="/kobis/business/comm/bord/insertTip.do">정보수정요청 등록</a>
# </li>
# </ul>
# </li>
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/comm/user/openLogin.do">로그인</a>
# <ul class="ovf overdepth">
# </ul>
# </li>
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/comm/user/openRegiUser.do">회원가입</a>
# <ul class="ovf overdepth">
# </ul>
# </li>
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/comm/comm/openFaq.do">FAQ</a>
# <ul class="ovf overdepth">
# </ul>
# </li>
# <li class="depth2">
# <a class="tit_sub" href="/kobis/business/sati/findSatiReqList.do">설문조사</a>
# <ul class="ovf overdepth">
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <!-- container -->
# <div id="container">
# <div id="snb">
# <h2 class="blind">
#             	영화정보검색
#             </h2>
# <h3>
#             	영화정보검색
#             </h3>
# <ul class="list_snb">
# <!-- 메뉴 대시보드 제거 하드코딩 c:choose 삭제 -->
# <li no="101">
# <strong class="tit"><a href="/kobis/business/mast/mvie/searchMovieList.do">영화</a></strong>
# <a class="hidetxt" href="javascript:;"><span class="ico_comm">펼쳐보기</span></a>
# <ul class="list_submenu">
# <!-- 메뉴 하드코딩 c:choose 제거2 -->
# <li no="241">
# <a class="block" href="/kobis/business/mast/mvie/searchMovieList.do">영화정보</a>
# <ul>
# </ul>
# </li>
# <!-- 메뉴 하드코딩 c:choose 제거2 -->
# <li no="360">
# <a class="block" href="/kobis/business/mast/mvie/findOpenScheduleList.do">개봉스케줄</a>
# <ul>
# </ul>
# </li>
# <!-- 메뉴 하드코딩 c:choose 제거2 -->
# <li no="243">
# <a class="block" href="/kobis/business/mast/mvie/searchPrdtList.do">한국영화 제작상황판</a>
# <ul>
# </ul>
# </li>
# <!-- 메뉴 하드코딩 c:choose 제거2 -->
# <li no="363">
# <a class="block" href="/kobis/business/mast/mvie/findDiverMovList.do">독립·예술영화</a>
# <ul>
# </ul>
# </li>
# </ul>
# </li>
# <!-- 메뉴 대시보드 제거 하드코딩 c:choose 삭제 -->
# <li no="102">
# <strong class="tit"><a href="/kobis/business/mast/peop/searchPeopleList.do">영화인</a></strong>
# </li>
# <!-- 메뉴 대시보드 제거 하드코딩 c:choose 삭제 -->
# <li no="255">
# <strong class="tit"><a href="/kobis/business/mast/comp/searchCompanyList.do">영화사</a></strong>
# </li>
# <!-- 메뉴 대시보드 제거 하드코딩 c:choose 삭제 -->
# <li no="365">
# <strong class="tit"><a href="/kobis/business/mast/thea/findTheaterInfoList.do">영화상영관</a></strong>
# <a class="hidetxt" href="javascript:;"><span class="ico_comm">펼쳐보기</span></a>
# <ul class="list_submenu">
# <!-- 메뉴 하드코딩 c:choose 제거2 -->
# <li no="547">
# <a class="block" href="/kobis/business/mast/thea/findTheaterInfoList.do">영화상영관정보</a>
# <ul>
# </ul>
# </li>
# <!-- 메뉴 하드코딩 c:choose 제거2 -->
# <li no="570">
# <a class="block" href="/kobis/business/mast/thea/findAreaTheaterStat.do">지역별 영화상영관현황</a>
# <ul>
# </ul>
# </li>
# <!-- 메뉴 하드코딩 c:choose 제거2 -->
# <li no="1260">
# <a class="block" href="/kobis/business/mast/thea/findShowHistorySc.do">상영내역</a>
# <ul>
# </ul>
# </li>
# <!-- 메뉴 하드코딩 c:choose 제거2 -->
# <li no="368">
# <a class="block" href="/kobis/business/mast/thea/findTheaterSchedule.do">상영스케줄</a>
# <ul>
# </ul>
# </li>
# <!-- 메뉴 하드코딩 c:choose 제거2 -->
# <li no="370">
# <a class="block" href="/kobis/business/mast/thea/findScreenQuota.do">스크린쿼터내역</a>
# <ul>
# </ul>
# </li>
# <!-- 메뉴 하드코딩 c:choose 제거2 -->
# <li no="371">
# <a class="block" href="/kobis/business/mast/thea/findArtScreenStat.do">전용상영관 현황</a>
# <ul>
# </ul>
# </li>
# <!-- 메뉴 하드코딩 c:choose 제거2 -->
# <li no="1331">
# <a class="block" href="/kobis/business/mast/thea/findArtShowHistory.do">전용상영관 상영내역</a>
# <ul>
# </ul>
# </li>
# </ul>
# </li>
# <!-- 메뉴 대시보드 제거 하드코딩 c:choose 삭제 -->
# <li no="103">
# <strong class="tit"><a href="/kobis/business/mast/fest/searchUserFestInfoList.do">영화제</a></strong>
# </li>
# <!-- 메뉴 대시보드 제거 하드코딩 c:choose 삭제 -->
# <li no="170">
# <strong class="tit"><a href="/kobis/business/mast/mvie/searchUserMovCdList.do">코드검색 및 등록</a></strong>
# <a class="hidetxt" href="javascript:;"><span class="ico_comm">펼쳐보기</span></a>
# <ul class="list_submenu">
# <!-- 메뉴 하드코딩 c:choose 제거2 -->
# <li no="171">
# <a class="block" href="/kobis/business/mast/mvie/searchUserMovCdList.do">영화코드</a>
# <ul>
# </ul>
# </li>
# <!-- 메뉴 하드코딩 c:choose 제거2 -->
# <li no="373">
# <a class="block" href="/kobis/business/mast/send/findSenderCodeList.do">전송사업자코드</a>
# <ul>
# </ul>
# </li>
# <!-- 메뉴 하드코딩 c:choose 제거2 -->
# <li no="375">
# <a class="block" href="/kobis/business/mast/thea/findTheaterCodeList.do">영화상영관코드</a>
# <ul>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div id="content">
# <!-- 타이틀 & 현재 페이지 위치 -->
# <div class="hd">
# <h4 class="tit" no="547">
# <img alt="영화상영관정보" src="/kobis/web/comm/images/mast/title_cinemainfo.gif"/>
# </h4>
# <strong class="blind">영화상영관정보</strong>
# <ul class="locate">
# <li><a href="/kobis/business/main/main.do"><span class="ico_comm">홈</span></a></li>
# <li><a href="/kobis/business/mast/mvie/searchMovieList.do">영화정보검색</a></li>
# <li><a href="/kobis/business/mast/thea/findTheaterInfoList.do">영화상영관</a></li>
# <li> <strong>영화상영관정보</strong></li>
# </ul>
# </div>
# <!-- //타이틀 & 현재 페이지 위치 -->
# <div class="box_gray">
# <p class="dot01"><span class="fwb">[영화상영관정보]</span>는 KOBIS(영화관입장권통합전산망)에 가입되어 영업상태인 영화상영관을 기본정보로 제공하고 있습니다.</p>
# <p class="dot01">영화상영관수, 스크린수는 휴관, 폐업, 신규등록, 재개관 등의 사유로 검색 시점에 따라 수시 변동될 수 있으며, 관리 및 집계기준에 따라 영화관수 및 스크린수는 차이가 있을 수 있습니다.</p>
# <p class="dot01">KOBIS에서 제공되는 영화상영관정보 중에는 전송사업자의 요청에 의해, 일부 영화상영관과 스크린은 아래와 같이 코드관리되고 있으니, 이용에 참고하시기 바랍니다.</p>
# <p class="dot03">물리적으로 1개의 영화관이지만, 2개의 영화관코드로 관리하고 있는 영화상영관(예: CGV CINE de CHEF 6개 스크린, 롯데시네마 샤롯데 9개 스크린)</p>
# <p class="dot03">상설영화관내 별도 스크린코드로 운영하는 비상설상영장이 일부 포함된 영화상영관(예: CGV 36개 등 총 40개 스크린 <!-- 기타 3개 총 12개 스크린 -->)</p>
# <p class="dot03">자동차극장 15개 영화관(21개 스크린) 운영 중 (2024.09 현재)</p>
# <p class="dot03"><span class="fwb">[관련법 용어]</span></p>
# <p class="dot03">법 제2조(정의) : “영화상영관”은 영리를 목적으로 영화를 상영하는 장소 또는 시설(단, 비상설상영장은 제외함)</p>
# <p class="dot03">※시행령 제2조(비상설상영장) : 영화상영일수가 120일 이내이고 계속상영기간이 30일 이내인 영화상영 장소 또는 시설</p>
# <p class="dot03">법 제36조(영화상영관의 등록) : “영화상영관”은 소재지를 관할하는 시군구에 영화상영관 등록을 하여야 함</p>
# </div>
# <div class="f_sch">
# <div class="tar">
# <a class="btn_small" href="javascript:;" onclick="fn_searchList('excel');return false;">엑셀</a>
# </div>
# <form action="findTheaterInfoList.do" id="searchForm" method="post" name="searchForm">
# <input name="CSRFToken" type="hidden" value="C_Blc0Gt76azZjdreWoScGTRgQX6b6btzz9FZt1KSZU">
# <input id="pageIndex" name="pageIndex" type="hidden" value=""/>
# <input id="theaCd" name="theaCd" type="hidden" value=""/>
# <div class="ins">
# <div class="item">
# <strong class="dot01">영화상영관명</strong>
# <div class="tf_comm">
# <input class="tf" id="sTheaNm" name="sTheaNm" type="text" value=""/>
# </div>
# </div>
# <div class="item">
# <strong class="dot01">영화상영관코드</strong>
# <div class="tf_comm">
# <input class="tf" id="sTheaCd" name="sTheaCd" type="text" value=""/>
# </div>
# </div>
# <div class="item">
# <strong class="dot01">영화상영관구분</strong>
# <div class="slt_comm">
# <select class="slt" id="sPermYn" name="sPermYn">
# <option value="">전체</option>
# <option value="Y">상설</option>
# <option value="N">비상설</option>
# </select>
# </div>
# </div>
# <div class="item">
# <strong class="dot01">가입여부</strong>
# <div class="slt_comm">
# <select class="slt" id="sJoinYn" name="sJoinYn">
# <option value="">전체</option>
# <option value="Y">가입</option>
# <option value="N">미가입</option>
# </select>
# </div>
# </div>
# <div class="item">
# <strong class="dot01">광역단체</strong>
# <div class="slt_comm">
# <select class="slt" id="sWideareaCd" name="sWideareaCd">
# <option value="">전체</option>
# <option value="0105001">서울시</option>
# <option value="0105002">경기도</option>
# <option value="0105003">강원도</option>
# <option value="0105004">충청북도</option>
# <option value="0105005">충청남도</option>
# <option value="0105006">경상북도</option>
# <option value="0105007">경상남도</option>
# <option value="0105008">전라북도</option>
# <option value="0105009">전라남도</option>
# <option value="0105010">제주도</option>
# <option value="0105011">부산시</option>
# <option value="0105012">대구시</option>
# <option value="0105013">대전시</option>
# <option value="0105014">울산시</option>
# <option value="0105015">인천시</option>
# <option value="0105016">광주시</option>
# <option value="0105017">세종시</option>
# </select>
# </div>
# </div>
# <div class="item">
# <strong class="dot01">기초단체</strong>
# <div class="slt_comm">
# <select class="slt" id="sBasareaCd" name="sBasareaCd">
# <option value="">전체</option>
# </select>
# </div>
# </div>
# <div class="item">
# <strong class="dot01">영업상태</strong>
# <div class="slt_comm">
# <select class="slt" id="sSaleStat" name="sSaleStat">
# <option value="">전체</option>
# <option selected="selected" value="018201">영업</option>
# <option value="018202">휴업</option>
# <option value="018203">폐업</option>
# </select>
# </div>
# </div>
# <div class="item">
# <strong class="dot01">전송사업자</strong>
# <div class="slt_comm">
# <select class="slt" id="sSenderCd" name="sSenderCd">
# <option value="">전체</option>
# <option value="A07">현대중공업(주)</option>
# <option value="A08">문화인</option>
# <option value="A09">(재) 영화의전당</option>
# <option value="A10">(주)디트릭스 </option>
# <option value="A11">(주)더브이엑스</option>
# <option value="A12">(주)유유코리아</option>
# <option value="A14">(주)대한에스엠</option>
# <option value="A15">(주)에스아이티랩</option>
# <option value="B01">CJ올리브네트웍스(주)</option>
# <option value="B02">롯데컬처웍스(주)롯데시네마</option>
# <option value="B07">메가박스(주)</option>
# <option value="B08">CJ올리브네트웍스(주)01</option>
# <option value="B09">(주)씨네큐</option>
# </select>
# </div>
# </div>
# <div class="wrap_btn">
# <button class="btn_blue" onclick="fn_searchList();" type="button">조회</button>
# <button class="btn_gray" onclick="fn_searchReset();" type="button">초기화</button>
# </div>
# </div>
# </input></form>
# </div>
# <div class="rst_sch">
# <div class="hd_rst">
# <span class="total"><em class="fwb">총 615건</em></span>
# </div>
# <table class="tbl_comm">
# <caption class="blind">검색 결과</caption>
# <colgroup>
# <col width="8%"/>
# <col width="8%"/>
# <col width="8%"/>
# <col width="16%"/>
# <col width="8%"/>
# <col width="8%"/>
# <col width="8%"/>
# <col width="8%"/>
# <col width="12%"/>
# <col width="8%"/>
# <col width="8%"/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">광역단체</th>
# <th scope="col">기초단체</th>
# <th scope="col">영화상영관코드</th>
# <th scope="col">영화상영관명</th>
# <th scope="col">스크린수</th>
# <th scope="col">좌석수</th>
# <th scope="col">상설여부</th>
# <th scope="col">가입여부</th>
# <th scope="col">전송사업자명</th>
# <th scope="col">개관일</th>
# <th scope="col">영업상태</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>서울시</td>
# <td>강서구</td>
# <td>001228</td>
# <td class="tal" title="메가박스 화곡"><span class="ellip per90"><a href="#none" onclick="javascript:fn_detail(event, $(this), '001228');return false;">메가박스 화곡</a></span></td>
# <td class="tar">5</td>
# <td class="tar">851</td>
# <td>상설</td>
# <td>가입</td>
# <td class="tal" title="메가박스(주)"><span class="ellip per90">메가박스(주)</span></td>
# <td>2015-05-29</td>
# <td class="last-child">영업</td>
# </tr>
# <tr class="even">
# <td>경상남도</td>
# <td>진주시</td>
# <td>007090</td>
# <td class="tal" title="CGV 진주혁신"><span class="ellip per90"><a href="#none" onclick="javascript:fn_detail(event, $(this), '007090');return false;">CGV 진주혁신</a></span></td>
# <td class="tar">7</td>
# <td class="tar">724</td>
# <td>상설</td>
# <td>가입</td>
# <td class="tal" title="CJ올리브네트웍스(주)"><span class="ellip per90">CJ올리브네트웍스(주)</span></td>
# <td>2020-09-28</td>
# <td class="last-child">영업</td>
# </tr>
# <tr>
# <td>광주시</td>
# <td>동구</td>
# <td>016047</td>
# <td class="tal" title="CGV 광주금남로"><span class="ellip per90"><a href="#none" onclick="javascript:fn_detail(event, $(this), '016047');return false;">CGV 광주금남로</a></span></td>
# <td class="tar">9</td>
# <td class="tar">936</td>
# <td>상설</td>
# <td>가입</td>
# <td class="tal" title="CJ올리브네트웍스(주)"><span class="ellip per90">CJ올리브네트웍스(주)</span></td>
# <td>2019-04-26</td>
# <td class="last-child">영업</td>
# </tr>
# <tr class="even">
# <td>부산시</td>
# <td>부산진구</td>
# <td>011080</td>
# <td class="tal" title="메가박스 서면대한"><span class="ellip per90"><a href="#none" onclick="javascript:fn_detail(event, $(this), '011080');return false;">메가박스 서면대한</a></span></td>
# <td class="tar">4</td>
# <td class="tar">661</td>
# <td>상설</td>
# <td>가입</td>
# <td class="tal" title="메가박스(주)"><span class="ellip per90">메가박스(주)</span></td>
# <td>2024-09-26</td>
# <td class="last-child">영업</td>
# </tr>
# <tr>
# <td>부산시</td>
# <td>부산진구</td>
# <td>011067</td>
# <td class="tal" title="CGV 서면삼정타워"><span class="ellip per90"><a href="#none" onclick="javascript:fn_detail(event, $(this), '011067');return false;">CGV 서면삼정타워</a></span></td>
# <td class="tar">8</td>
# <td class="tar">1,133</td>
# <td>상설</td>
# <td>가입</td>
# <td class="tal" title="CJ올리브네트웍스(주)"><span class="ellip per90">CJ올리브네트웍스(주)</span></td>
# <td>2019-07-04</td>
# <td class="last-child">영업</td>
# </tr>
# <tr class="even">
# <td>경기도</td>
# <td>수원시</td>
# <td>002303</td>
# <td class="tal" title="메가박스 수원AK플라자"><span class="ellip per90"><a href="#none" onclick="javascript:fn_detail(event, $(this), '002303');return false;">메가박스 수원AK플라자</a></span></td>
# <td class="tar">8</td>
# <td class="tar">1,918</td>
# <td>상설</td>
# <td>가입</td>
# <td class="tal" title="메가박스(주)"><span class="ellip per90">메가박스(주)</span></td>
# <td>2023-08-11</td>
# <td class="last-child">영업</td>
# </tr>
# <tr>
# <td>전라남도</td>
# <td>화순군</td>
# <td>009062</td>
# <td class="tal" title="화순시네마"><span class="ellip per90"><a href="#none" onclick="javascript:fn_detail(event, $(this), '009062');return false;">화순시네마</a></span></td>
# <td class="tar">2</td>
# <td class="tar">124</td>
# <td>상설</td>
# <td>가입</td>
# <td class="tal" title="(주)디트릭스 "><span class="ellip per90">(주)디트릭스 </span></td>
# <td>2018-02-12</td>
# <td class="last-child">영업</td>
# </tr>
# <tr class="even">
# <td>인천시</td>
# <td>남동구</td>
# <td>015005</td>
# <td class="tal" title="CGV 인천"><span class="ellip per90"><a href="#none" onclick="javascript:fn_detail(event, $(this), '015005');return false;">CGV 인천</a></span></td>
# <td class="tar">15</td>
# <td class="tar">3,678</td>
# <td>상설</td>
# <td>가입</td>
# <td class="tal" title="CJ올리브네트웍스(주)"><span class="ellip per90">CJ올리브네트웍스(주)</span></td>
# <td>1999-12-18</td>
# <td class="last-child">영업</td>
# </tr>
# <tr>
# <td>충청북도</td>
# <td>청주시</td>
# <td>004055</td>
# <td class="tal" title="롯데시네마 오송"><span class="ellip per90"><a href="#none" onclick="javascript:fn_detail(event, $(this), '004055');return false;">롯데시네마 오송</a></span></td>
# <td class="tar">6</td>
# <td class="tar">512</td>
# <td>상설</td>
# <td>가입</td>
# <td class="tal" title="롯데컬처웍스(주)롯데시네마"><span class="ellip per90">롯데컬처웍스(주)롯데시네마</span></td>
# <td>2024-09-11</td>
# <td class="last-child">영업</td>
# </tr>
# <tr class="even">
# <td>서울시</td>
# <td>강남구</td>
# <td>001242</td>
# <td class="tal" title="픽처하우스"><span class="ellip per90"><a href="#none" onclick="javascript:fn_detail(event, $(this), '001242');return false;">픽처하우스</a></span></td>
# <td class="tar">1</td>
# <td class="tar">59</td>
# <td>상설</td>
# <td>가입</td>
# <td class="tal" title="메가박스(주)"><span class="ellip per90">메가박스(주)</span></td>
# <td>2017-01-11</td>
# <td class="last-child">영업</td>
# </tr>
# </tbody>
# </table>
# <div class="hd_rst">
# <div class="fr marginT7"><a class="btn_small" href="javascript:;" onclick="fn_searchList('excel');return false;">엑셀</a></div>
# </div>
# <form action="findTheaterInfoList.do" id="pagingForm" method="post" name="pagingForm">
# <input name="CSRFToken" type="hidden" value="C_Blc0Gt76azZjdreWoScGTRgQX6b6btzz9FZt1KSZU">
# <input name="searchOpen" type="hidden" value="">
# <div class="paging">
# <ul class="list_page">
# <li><a class="on" href="#none" onclick="goPage('1')">1</a></li>
# <li><a href="#none" onclick="goPage('2')">2</a></li>
# <li><a href="#none" onclick="goPage('3')">3</a></li>
# <li><a href="#none" onclick="goPage('4')">4</a></li>
# <li><a href="#none" onclick="goPage('5')">5</a></li>
# <li><a href="#none" onclick="goPage('6')">6</a></li>
# <li><a href="#none" onclick="goPage('7')">7</a></li>
# <li><a href="#none" onclick="goPage('8')">8</a></li>
# <li><a href="#none" onclick="goPage('9')">9</a></li>
# <li><a href="#none" onclick="goPage('10')">10</a></li>
# </ul>
# <a class="btn next" href="javascript:;" onclick="goPage('11');return false;"><span class="ico_comm">다음</span></a>
# <a class="btn last" href="javascript:;" onclick="goPage('62');return false;"><span class="ico_comm">마지막</span></a>
# </div>
# </input></input></form>
# <!-- <div class="paging">
#               	<a href="javascript:;" class="btn first"><span class="ico_comm">처음</span></a>
#               	<a href="javascript:;" class="btn prev"><span class="ico_comm">이전</span></a>
#                 <ul class="list_page">
#                 	<li><a href="javascript:;" class="on">1</a></li>
#                 	<li><a href="javascript:;">2</a></li>
#                 	<li><a href="javascript:;">3</a></li>
#                 	<li><a href="javascript:;">4</a></li>
#                 	<li><a href="javascript:;">5</a></li>
#                 </ul>
#               	<a href="javascript:;" class="btn next"><span class="ico_comm">다음</span></a>
#               	<a href="javascript:;" class="btn last"><span class="ico_comm">마지막</span></a>
#               </div> -->
# </div>
# </div>
# </div>
# <!-- // container -->
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="/kobis/web/comm/commjs/gtag.js?id=UA-127072686-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'UA-127072686-1');
# </script>
# <!-- AceCounter Log Gathering Script V.8.0.AMZ2019080601 -->
# <script language="javascript">
# 	var _AceGID=(function(){var Inf=['gtt6.acecounter.com','8080','AB2A31560820885','AW','0','NaPm,Ncisy','ALL','0']; var _CI=(!_AceGID)?[]:_AceGID.val;var _N=0;var _T=new Image(0,0);if(_CI.join('.').indexOf(Inf[3])<0){ _T.src ="https://"+ Inf[0] +'/?cookie'; _CI.push(Inf);  _N=_CI.length; } return {o: _N,val:_CI}; })();
# 	var _AceCounter=(function(){var G=_AceGID;var _sc=document.createElement('script');var _sm=document.getElementsByTagName('script')[0];if(G.o!=0){var _A=G.val[G.o-1];var _G=(_A[0]).substr(0,_A[0].indexOf('.'));var _C=(_A[7]!='0')?(_A[2]):_A[3];var _U=(_A[5]).replace(/\,/g,'_');_sc.src='https:'+'//cr.acecounter.com/Web/AceCounter_'+_C+'.js?gc='+_A[2]+'&py='+_A[4]+'&gd='+_G+'&gp='+_A[1]+'&up='+_U+'&rd='+(new Date().getTime());_sm.parentNode.insertBefore(_sc,_sm);return _sc.src;}})();
# </script>
# <noscript><img alt="" border="0" height="0" src="//gtt6.acecounter.com:8080/?uid=AB2A31560820885&amp;je=n&amp;" width="0"/></noscript>
# <!-- AceCounter Log Gathering Script End -->
# <script language="javascript">
# function familySite(){
#    if (document.getElementById("familySite").value == "a2") {
# 	   window.open ("https://www.kofic.or.kr");
#    } else if (document.getElementById("familySite").value == "a3") {
# 	   window.open ("https://www.kobis.or.kr/kobisopenapi/homepg/main/main.do");
#    }
# }
# </script>
# <!-- AceCounter Log Gathering Script End -->
# <div id="footer">
# <div class="cont">
# <div class="foot_link">
# <ul class="fl">
# <li><a href="/kobis/business/comm/comm/openKobisIntro.do">KOBIS 소개</a></li>
# <li><a href="/kobis/business/comm/comm/openCinemAconnect.do">영화상영관 연동안내</a></li>
# <li><a href="/kobis/business/comm/comm/openPrivacyAgreement.do">개인정보처리방침</a></li>
# <li><a href="/kobis/business/comm/ntfy/findCustomerNotifyList.do">고객센터</a></li>
# <li><a href="/kobis/business/comm/bord/listMyTip.do?bizLogicType=3">정보수정요청</a></li>
# <li><a href="/kobis/business/comm/comm/openSiteMap.do">사이트맵</a></li>
# </ul>
# <div class="sites">
# <select class="slt" id="familySite" name="familySite" onchange="familySite();">
# <option value="a1">Family Site</option>
# <option value="a2">KOFIC</option>
# <option value="a3">OpenAPI</option>
# </select>
# </div>
# </div>
# <div class="foot_info">
# <strong class="fl"><a class="block" href="#none"><img alt="KOFIC 영화진흥위원회 - Korean Film Council" src="/kobis/web/comm/images/comm/footer_logo.png"/></a></strong>
# <div class="ovf">
# <span style="margin-right: 17px;">(48058) 부산광역시 해운대구 수영강변대로 130(우동)</span><br/>
# <span style="margin-right: 17px;">02-6261-6573</span>
# <span style="margin-right: 17px;">E-mail: kobis@kofic.or.kr</span>
# <span style="margin-right: 17px;">이용시간: 09:00 ~ 18:00(평일)</span>
# <p>COPYRIGHT(C) KOREAN FILM COUNCIL ALL RIGHTS RESERVED.</p>
# </div>
# </div>
# </div>
# </div>
# </link></div>
# <div id="div_theaterDetail"></div>
# </body>
# </html>

# %%
table=soup.find("table")
rows=table.find('tbody').find_all('tr')

print(rows)
# Out:
# [<tr>
# <td>서울시</td>
# <td>강서구</td>
# <td>001228</td>
# <td class="tal" title="메가박스 화곡"><span class="ellip per90"><a href="#none" onclick="javascript:fn_detail(event, $(this), '001228');return false;">메가박스 화곡</a></span></td>
# <td class="tar">5</td>
# <td class="tar">851</td>
# <td>상설</td>
# <td>가입</td>
# <td class="tal" title="메가박스(주)"><span class="ellip per90">메가박스(주)</span></td>
# <td>2015-05-29</td>
# <td class="last-child">영업</td>
# </tr>, <tr class="even">
# <td>경상남도</td>
# <td>진주시</td>
# <td>007090</td>
# <td class="tal" title="CGV 진주혁신"><span class="ellip per90"><a href="#none" onclick="javascript:fn_detail(event, $(this), '007090');return false;">CGV 진주혁신</a></span></td>
# <td class="tar">7</td>
# <td class="tar">724</td>
# <td>상설</td>
# <td>가입</td>
# <td class="tal" title="CJ올리브네트웍스(주)"><span class="ellip per90">CJ올리브네트웍스(주)</span></td>
# <td>2020-09-28</td>
# <td class="last-child">영업</td>
# </tr>, <tr>
# <td>광주시</td>
# <td>동구</td>
# <td>016047</td>
# <td class="tal" title="CGV 광주금남로"><span class="ellip per90"><a href="#none" onclick="javascript:fn_detail(event, $(this), '016047');return false;">CGV 광주금남로</a></span></td>
# <td class="tar">9</td>
# <td class="tar">936</td>
# <td>상설</td>
# <td>가입</td>
# <td class="tal" title="CJ올리브네트웍스(주)"><span class="ellip per90">CJ올리브네트웍스(주)</span></td>
# <td>2019-04-26</td>
# <td class="last-child">영업</td>
# </tr>, <tr class="even">
# <td>부산시</td>
# <td>부산진구</td>
# <td>011080</td>
# <td class="tal" title="메가박스 서면대한"><span class="ellip per90"><a href="#none" onclick="javascript:fn_detail(event, $(this), '011080');return false;">메가박스 서면대한</a></span></td>
# <td class="tar">4</td>
# <td class="tar">661</td>
# <td>상설</td>
# <td>가입</td>
# <td class="tal" title="메가박스(주)"><span class="ellip per90">메가박스(주)</span></td>
# <td>2024-09-26</td>
# <td class="last-child">영업</td>
# </tr>, <tr>
# <td>부산시</td>
# <td>부산진구</td>
# <td>011067</td>
# <td class="tal" title="CGV 서면삼정타워"><span class="ellip per90"><a href="#none" onclick="javascript:fn_detail(event, $(this), '011067');return false;">CGV 서면삼정타워</a></span></td>
# <td class="tar">8</td>
# <td class="tar">1,133</td>
# <td>상설</td>
# <td>가입</td>
# <td class="tal" title="CJ올리브네트웍스(주)"><span class="ellip per90">CJ올리브네트웍스(주)</span></td>
# <td>2019-07-04</td>
# <td class="last-child">영업</td>
# </tr>, <tr class="even">
# <td>경기도</td>
# <td>수원시</td>
# <td>002303</td>
# <td class="tal" title="메가박스 수원AK플라자"><span class="ellip per90"><a href="#none" onclick="javascript:fn_detail(event, $(this), '002303');return false;">메가박스 수원AK플라자</a></span></td>
# <td class="tar">8</td>
# <td class="tar">1,918</td>
# <td>상설</td>
# <td>가입</td>
# <td class="tal" title="메가박스(주)"><span class="ellip per90">메가박스(주)</span></td>
# <td>2023-08-11</td>
# <td class="last-child">영업</td>
# </tr>, <tr>
# <td>전라남도</td>
# <td>화순군</td>
# <td>009062</td>
# <td class="tal" title="화순시네마"><span class="ellip per90"><a href="#none" onclick="javascript:fn_detail(event, $(this), '009062');return false;">화순시네마</a></span></td>
# <td class="tar">2</td>
# <td class="tar">124</td>
# <td>상설</td>
# <td>가입</td>
# <td class="tal" title="(주)디트릭스 "><span class="ellip per90">(주)디트릭스 </span></td>
# <td>2018-02-12</td>
# <td class="last-child">영업</td>
# </tr>, <tr class="even">
# <td>인천시</td>
# <td>남동구</td>
# <td>015005</td>
# <td class="tal" title="CGV 인천"><span class="ellip per90"><a href="#none" onclick="javascript:fn_detail(event, $(this), '015005');return false;">CGV 인천</a></span></td>
# <td class="tar">15</td>
# <td class="tar">3,678</td>
# <td>상설</td>
# <td>가입</td>
# <td class="tal" title="CJ올리브네트웍스(주)"><span class="ellip per90">CJ올리브네트웍스(주)</span></td>
# <td>1999-12-18</td>
# <td class="last-child">영업</td>
# </tr>, <tr>
# <td>충청북도</td>
# <td>청주시</td>
# <td>004055</td>
# <td class="tal" title="롯데시네마 오송"><span class="ellip per90"><a href="#none" onclick="javascript:fn_detail(event, $(this), '004055');return false;">롯데시네마 오송</a></span></td>
# <td class="tar">6</td>
# <td class="tar">512</td>
# <td>상설</td>
# <td>가입</td>
# <td class="tal" title="롯데컬처웍스(주)롯데시네마"><span class="ellip per90">롯데컬처웍스(주)롯데시네마</span></td>
# <td>2024-09-11</td>
# <td class="last-child">영업</td>
# </tr>, <tr class="even">
# <td>서울시</td>
# <td>강남구</td>
# <td>001242</td>
# <td class="tal" title="픽처하우스"><span class="ellip per90"><a href="#none" onclick="javascript:fn_detail(event, $(this), '001242');return false;">픽처하우스</a></span></td>
# <td class="tar">1</td>
# <td class="tar">59</td>
# <td>상설</td>
# <td>가입</td>
# <td class="tal" title="메가박스(주)"><span class="ellip per90">메가박스(주)</span></td>
# <td>2017-01-11</td>
# <td class="last-child">영업</td>
# </tr>]

# %%
columns=rows[0].find_all('td')
text_columns=[]
for i in columns:
    text_columns.append(i.get_text())
print(text_columns)
# Out:
# ['서울시', '강서구', '001228', '메가박스 화곡', '5', '851', '상설', '가입', '메가박스(주)', '2015-05-29', '영업']
